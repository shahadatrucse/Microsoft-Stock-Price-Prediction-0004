# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
plt.style.use('fivethirtyeight')
data=pd.read_csv(r"C:\Users\DELL USER\Downloads\MSFT.csv")
data.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2020-07-08  210.070007  213.259995  208.690002  212.830002  210.789032
# 1  2020-07-09  216.330002  216.380005  211.470001  214.320007  212.264740
# 2  2020-07-10  213.619995  214.080002  211.080002  213.669998  211.620972
# 3  2020-07-13  214.479996  215.800003  206.500000  207.070007  205.084259
# 4  2020-07-14  206.130005  208.850006  202.029999  208.350006  206.351974
#
#      Volume
# 0  33600000
# 1  33121700
# 2  26177600
# 3  38135600
# 4  37591800

# %%
plt.figure(figsize=(10,4))
plt.title("Microsoft Stock Price Prediction")
plt.xlabel("Date")
plt.ylabel("Close")
plt.plot(data["Close"])
plt.show()

# %%
print(data.corr())
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.995767  0.994911  0.989490   0.989598 -0.292656
# High       0.995767  1.000000  0.995100  0.995081   0.995079 -0.267697
# Low        0.994911  0.995100  1.000000  0.996137   0.996295 -0.330101
# Close      0.989490  0.995081  0.996137  1.000000   0.999854 -0.307046
# Adj Close  0.989598  0.995079  0.996295  0.999854   1.000000 -0.308906
# Volume    -0.292656 -0.267697 -0.330101 -0.307046  -0.308906  1.000000

# %%
sns.heatmap(data.corr())
plt.show()

# %%
x=data[["Open","High","Low"]]
y=data["Close"]
x=x.to_numpy()
y=y.to_numpy()
y=y.reshape(-1,1)
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.1,random_state=42)
# Out:
# array([[251.      , 252.080002, 249.559998],
#        [214.899994, 215.      , 211.570007],
#        [270.690002, 271.359985, 269.600006],
#        [213.619995, 214.080002, 211.080002],
#        [257.820007, 260.200012, 256.839996],
#        [266.190002, 268.899994, 265.910004],
#        [214.5     , 216.5     , 209.720001],
#        [207.160004, 207.649994, 203.139999],
#        [251.429993, 252.940002, 250.75    ],
#        [241.869995, 244.759995, 241.380005],
#        [214.169998, 214.770004, 210.309998],
#        [212.169998, 216.490005, 211.940002],
#        [214.509995, 217.320007, 213.350006],
#        [222.039993, 224.119995, 221.149994],
#        [214.75    , 220.110001, 214.720001],
#        [222.889999, 231.149994, 219.399994],
#        [205.059998, 208.100006, 202.080002],
#        [211.490005, 212.100006, 209.25    ],
#        [221.699997, 223.      , 219.679993],
#        [227.970001, 232.860001, 227.350006],
#        [237.009995, 237.300003, 233.449997],
#        [214.039993, 219.339996, 213.710007],
#        [234.009995, 235.820007, 233.229996],
#        [237.419998, 237.929993, 232.399994],
#        [213.860001, 216.25    , 212.850006],
#        [222.529999, 223.      , 214.809998]])

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)
data = pd.DataFrame(data={"Predicted Rate": ypred})
print(data.head())
# Out:
#    Predicted Rate
# 0      249.309998
# 1      211.080002
# 2      271.399994
# 3      211.080002
# 4      259.890015
